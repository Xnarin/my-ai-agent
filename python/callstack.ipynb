# %%
# call stack
# stack에 쌓이듯이 실행이 유지가 되고
# 함수가 call -> append
# 함수가 return -> pop

def func0():
    # 뭔갈 하다
    print(5)
    func1()
    print(0)

def func1():
    # 뭔갈 하다
    print(1)

def func3():
    # 뭔갈 하다
    print(4)
    func0()
    print(3)

func3()
