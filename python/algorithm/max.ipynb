# %%
# max함수를 쓰면 어떻게 되느냐?

lst = [1, 76, 3, 8, 45, 8, 3, 2, ]
print(max(lst))
movies = [{'adult': False, 'backdrop_path': '/qeQJx07rK2xm8SD2sJxFKhE7gs0.jpg', 'genre_ids': [878, 28, 12], 'id': 969681, 'original_language': 'en', 'original_title': 'Spider-Man: Brand New Day', 'overview': "Fighting crime full-time as Spider-Man in a world that doesn't remember him—and the pressure of seeing his old friends move on without him—sparks a change in Peter Parker he may not have the power to control. But that transformation might also be the only thing that can stop a shocking new threat to the city and those he loves - a powerful villain no one can even see.", 'popularity': 1872.4338, 'poster_path': '/iPOn6DinuVyLY17YM9mKuPofV08.jpg', 'release_date': '2026-07-29', 'softcore': False, 'title': 'Spider-Man: Brand New Day', 'video': False, 'vote_average': 7.886, 'vote_count': 1938}, {'adult': False, 'backdrop_path': '/r57L2UBLPKcHdZQYg8tagv9XqK2.jpg', 'genre_ids': [12, 28, 14], 'id': 1368337, 'original_language': 'en', 'original_title': 'The Odyssey', 'overview': 'Odysseus, the legendary King of Ithaca, embarks on a long and perilous journey home following the Trojan War. Throughout his voyage, he is forced to confront the whims of gods, mythological monsters, and trials that stretch both his cunning and his humanity to the breaking point.', 'popularity': 778.47, 'poster_path': '/5rhTDKUhPYvpdQIijFIs5VoWsON.jpg', 'release_date': '2026-07-15', 'softcore': False, 'title': 'The Odyssey', 'video': False, 'vote_average': 7.982, 'vote_count': 2962}, {'adult': False, 'backdrop_path': '/8sSKdEmlmqF4kJUd28SqthXC4yZ.jpg', 'genre_ids': [16, 10751, 35, 12], 'id': 1084244, 'original_language': 'en', 'original_title': 'Toy Story 5', 'overview': "When Bonnie receives a Lilypad tablet as a gift and becomes obsessed, Buzz, Woody, Jessie and the rest of the gang's jobs become exponentially harder when they have to go head to head with the all-new threat to playtime.", 'popularity': 388.1231, 'poster_path': '/sfQtVlIHljToOwYjhe21KPGzZWK.jpg', 'release_date': '2026-06-17', 'softcore': False, 'title': 'Toy Story 5', 'video': False, 'vote_average': 7.874, 'vote_count': 1106}]

# print(movies)

def get_vote_average(movie):
    return movie['vote_average']
    
for movie in movies:
    # vote_average = movie['vote_average']
    vote_average = get_vote_average(movie)

    print(vote_average)


# max, min, sorted 같은 비교를 해야하는 함수들은
# 기준을 잡아서 진행할 수 있습니다.

# key에는 함수 그 자체가 들어감.
max_vote_average = max(movies, key=get_vote_average)

print(max_vote_average)
print(max_vote_average['vote_average'])


# lamda라는 익명함수
# lambda 매개변수 : 리턴값

max_vote_average = max(movies, key=lambda movie : movie['vote_average'])
print(max_vote_average)

print(     (lambda x : x * 2)(3)   )
# Out:
# 76
# 7.886
# 7.982
# 7.874
# {'adult': False, 'backdrop_path': '/r57L2UBLPKcHdZQYg8tagv9XqK2.jpg', 'genre_ids': [12, 28, 14], 'id': 1368337, 'original_language': 'en', 'original_title': 'The Odyssey', 'overview': 'Odysseus, the legendary King of Ithaca, embarks on a long and perilous journey home following the Trojan War. Throughout his voyage, he is forced to confront the whims of gods, mythological monsters, and trials that stretch both his cunning and his humanity to the breaking point.', 'popularity': 778.47, 'poster_path': '/5rhTDKUhPYvpdQIijFIs5VoWsON.jpg', 'release_date': '2026-07-15', 'softcore': False, 'title': 'The Odyssey', 'video': False, 'vote_average': 7.982, 'vote_count': 2962}
# 7.982
# ...
