# %% [markdown]
# ### 공공 데이터 API
#
# 미세먼지(한국환경공단_에어코리아_대기오염정보)관련 API를 활용하여 다음 질문에 답하시오.

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# 1. `시도별 실시간 측정정보 조회`에서  확인 가능한 시도 이름을 전부 작성하시오.

# %%
import requests
from pprint import pprint

url = "https://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=vOfUqwkPhMItwFtxNSd8HT%2FDVnFJ2CKUyU6FfbazcYMgEn74PPkbLs%2BxPKu6hrthrxpmHIErWgaXWFG3IQ7gMw%3D%3D&sidoName=서울&returnType=json&ver=1.4"

try:
    response = requests.get(url)
    response.raise_for_status()

    data = response.json()

    body = data.get("response").get("body")
    items = body.get("items")

    # 값이 '-'인 측정소는 제외
    valid_items = []

    for item in items:
        pm25_value = item.get("pm25Value")

        if pm25_value is not None and pm25_value != "-":
            valid_items.append(item)

    worst_air = max(
        valid_items,
        key=lambda item: int(item.get("pm25Value"))
    )

    pprint(worst_air)

except Exception as e:
    print("오류 발생")
    print(e)
    time.sleep(1)
# Out:
# {'coFlag': None,
#  'coGrade': '1',
#  'coValue': '0.3',
#  'dataTime': '2026-08-21 13:00',
#  'khaiGrade': '2',
#  'khaiValue': '85',
#  'mangName': '도시대기',
#  'no2Flag': None,
#  'no2Grade': '1',
#  'no2Value': '0.015',
#  'o3Flag': None,
#  'o3Grade': '1',
#  'o3Value': '0.018',
#  'pm10Flag': None,
#  'pm10Grade': '2',
#  'pm10Grade1h': '2',
#  'pm10Value': '33',
#  'pm10Value24': '37',
#  'pm25Flag': None,
#  'pm25Grade': '2',
#  'pm25Grade1h': '2',
#  'pm25Value': '28',
#  'pm25Value24': '29',
#  'sidoName': '서울',
#  'so2Flag': None,
#  'so2Grade': '1',
#  'so2Value': '0.002',
#  'stationCode': '111131',
#  'stationName': '용산구'}

# %%
# 정답은 코드가 아닙니다
import requests

url = "https://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=vOfUqwkPhMItwFtxNSd8HT%2FDVnFJ2CKUyU6FfbazcYMgEn74PPkbLs%2BxPKu6hrthrxpmHIErWgaXWFG3IQ7gMw%3D%3D&sidoName=서울&returnType=json"


try :
    json_data = requests.get(url)
    json_data.raise_for_status()

    response = json_data.get('response')
    body = response.get('body')
    items = body.get('items')

    pprint(max(items, key = lambda item : item.get('pm25value')))


except Exception as e:
    print("오류 발생")
    print(e)
# Out:
# 오류 발생
# 'Response' object has no attribute 'get'

# %% [markdown]
# 2. `시도별 실시간 측정정보 조회`의 `서울`의 데이터에 대해, 초 미세먼지 농도가 가장 낮은 `stationName`을 찾으시오.
#     1. `시도별 실시간 측정정보 조회`의 `제주`의 데이터에 대해, 초 미세먼지 농도가 가장 낮은 `stationName`을 찾으시오.

# %% [markdown]
# 3. `시도별 실시간 측정정보 조회`의 `서울`의 데이터를 `stationName`으로 접근하기 쉬운 자료구조로 재구성하시오.

# %% [markdown]
# 4. `종로구`의 미세먼지 농도, 초미세먼지 농도의 1달치 데이터를 정리하시오.
